# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for nodes in range(3, 11):
    for exp in range(10):
        df = pd.read_csv(f'parameter_learning/{nodes}_{exp}_100000.csv', index_col=0)
        plt.plot(df)
        plt.title(f'{nodes}_{exp}')
        plt.show()

# %%
node_3 = np.array([15, 17, 20, 10, 15, 10, 10, 17, 18, 15])*100
node_4 = np.array([96, 65, 60, 40, 97, 40, 15, 16, 16])*100
node_5 = np.array([35, 100, 15, 100, 91, 15, 20, 95, 20, 50])*100
node_6 = np.array([18, 88, 15, 50, 100, 88, 15, 92, 20, 15])*100
node_7 = np.array([90, 93, 20, 86, 65, 80, 25, 15, 20, 93])*100
node_8 = np.array([86, 88, 15, 95, 75, 95, 40,15, 20, 20])*100
node_9 = np.array([93, 100, 70, 100, 86, 98, 40, 20, 18, 15])*100
node_10 = np.array([97, 100, 86, 96, 100, 50, 86, 89, 70])*100

# %%
data = {'nodes_3':node_3, 
        'nodes_4':node_4,
        'nodes_5':node_5,
        'nodes_6':node_6,
        'nodes_7':node_7,
        'nodes_8':node_8,
        'nodes_9':node_9,
        'nodes_10':node_10,
       }
box_data = [node_3, node_4, node_5, node_6, node_7, node_8, node_9, node_10]

# %%
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

box = ax.boxplot(box_data)
ax.set_xticklabels(range(3, 11))
plt.ylabel('train_size')
plt.xlabel('n_nodes')
plt.grid()
plt.show()

# %%
import plotly.graph_objects as go

labels = []
for i in range(len(box_data)):
    nodes_label = f"nodes={i+3}"
    labels.append(f"{nodes_label}")

fig = go.Figure()
for i in range(len(box_data)):
    fig.add_trace(go.Box(y=box_data[i], name=labels[i], showlegend=False))

fig.update_layout(
    title={
        'text': 'Parameter learning',
        'y': 0.9,
        'x': 0.46,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    yaxis_title="train_size",
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(len(labels))),
        ticktext=labels
    ),
    width=1000,
    height=600,
    font=dict(
        size=18,
        color="RebeccaPurple"
    )
)

fig.show()
# Out:
# <div>                            <div id="a3278a9e-d3d8-4bdf-808e-caf4129d9d06" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3278a9e-d3d8-4bdf-808e-caf4129d9d06")) {                    Plotly.newPlot(                        "a3278a9e-d3d8-4bdf-808e-caf4129d9d06",                        [{"name":"nodes=3","showlegend":false,"y":[1500,1700,2000,1000,1500,1000,1000,1700,1800,1500],"type":"box"},{"name":"nodes=4","showlegend":false,"y":[9600,6500,6000,4000,9700,4000,1500,1600,1600],"type":"box"},{"name":"nodes=5","showlegend":false,"y":[3500,10000,1500,10000,9100,1500,2000,9500,2000,5000],"type":"box"},{"name":"nodes=6","showlegend":false,"y":[1800,8800,1500,5000,10000,8800,1500,9200,2000,1500],"type":"box"},{"name":"nodes=7","showlegend":false,"y
# ...

# %%
data
# Out:
# {'nodes_3': [15, 17, 20, 10, 15, 10, 10, 17, 18, 15],
#  'nodes_4': [96, 65, 60, 40, 97, 40, 15, 16, 16],
#  'nodes_5': [35, 100, 15, 100, 91, 15, 20, 95, 20, 50],
#  'nodes_6': [18, 88, 15, 50, 100, 88, 15, 92, 20, 15],
#  'nodes_7': [90, 93, 20, 86, 65, 80, 25, 15, 20, 93],
#  'nodes_8': [86, 88, 15, 95, 75, 95, 40, 15, 20, 20],
#  'nodes_9': [93, 100, 70, 100, 86, 98, 40, 20, 18, 15],
#  'nodes_10': [97, 100, 86, 96, 100, 50, 86, 89, 70]}
